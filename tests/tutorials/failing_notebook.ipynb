# %% [markdown]
# # Failing notebook sentinel
#
# This notebook verifies that the tutorial test runner fails when notebook code fails.

# %%
failure_message = "intentional tutorial runner failure"
raise RuntimeError(failure_message)
